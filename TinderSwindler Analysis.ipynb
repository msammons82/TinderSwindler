# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('TinderSwindlerVersion2.csv')
df.head(20)
# Out:
#                          user_name                 user_location  \
# 0           globalnode.saito 🟥🐳🐈‍⬛  Travelling the World on Web3
# 1                  Ungovernable 🇧🇮                           NaN
# 2                        Adefolake                           NaN
# 3                              ✧ ☽                 Noord-Brabant
# 4                         chivo. 🥶                         PG/MD
# 5                             kira              Toronto, Ontario
# 6                   fogmistress698                           NaN
# 7                        melraunch                 East, England
# 8                     Pamela Power    Johannesburg, South Africa
# 9                     CaliMcCormac                           NaN
# 10                    🌸 Kevser M 🌸                         الله
# 11                       J. Prince                       Outchea
# 12               DonJulio 🤴🏿B.E. 🌎               Road to Riches
# ...

# %%
df.source.value_counts()
# Out:
# Twitter for iPhone                 47828
# Twitter for Android                18421
# Twitter Web App                     6865
# Twitter for iPad                     506
# TweetDeck                            495
#                                    ...
# PLANOLY                                1
# HaikuD2                                1
# Janetter for Android                   1
# Quick Tweet - just tweet simply        1
# DataScienceInfo                        1
# Name: source, Length: 210, dtype: int64

# %%
df.isnull().sum()
# Out:
# user_name             5
# user_location     18481
# user_created          0
# user_followers        0
# user_verified         0
# date                  0
# text                  0
# source                0
# is_retweet            0
# dtype: int64

# %%
df1 = df.dropna(subset=['user_location'])

# %%
df1.shape
# Out:
# (57732, 9)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,10))
sns.set(style='darkgrid')
ax = sns.countplot(y="user_location", data=df1, order=df1['user_location'].value_counts().index[0:20])

# %%
plt.figure(figsize=(15,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="source", data=df1, order=df1['source'].value_counts().index[0:5])

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.DataFrame(df1[['user_name', 'text','user_followers']])

# %%
plt.figure(figsize=(15,10))
sns.set(style="darkgrid")
ax = sns.countplot(x=df, data=df, order=df[df].value_counts().index[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <module>
#       1 plt.figure(figsize=(15,10))
#       2 sns.set(style="darkgrid")
# ----> 3 ax = sns.countplot(x=df, data=df, order=df[df].value_counts().index[1])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...
